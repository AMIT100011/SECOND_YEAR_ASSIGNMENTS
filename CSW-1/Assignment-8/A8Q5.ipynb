# %%
import numpy as np

sugar = np.array([90, 110, 150, 130, 95, 180])
result = np.empty(sugar.shape)

result[sugar < 100] = "Normal"
result[(sugar >= 100) & (sugar <= 139)] = "Pre-Diabetic"
result[sugar >= 140] = "Diabetic"

print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 sugar = np.array([90, 110, 150, 130, 95, 180])
#       4 result = np.empty(sugar.shape)
# ----> 5 result[sugar < 100] = "Normal"
#       6 result[(sugar >= 100) & (sugar <= 139)] = "Pre-Diabetic"
#       7 result[sugar >= 140] = "Diabetic"
#
# ValueError: could not convert string to float: 'Normal'
