# %%
import numpy as np
deg = np.array([0,30,45,60,90])
rad = np.deg2rad(deg)
print("Degrees:", deg)
print("Radians:", np.round(rad, 4))
print("Sin:", np.round(np.sin(rad), 4))
print("Cos:", np.round(np.cos(rad), 4))
print("Tan:", np.round(np.tan(rad), 2))
# Out:
# Degrees: [ 0 30 45 60 90]
# Radians: [0.     0.5236 0.7854 1.0472 1.5708]
# Sin: [0.     0.5    0.7071 0.866  1.    ]
# Cos: [1.     0.866  0.7071 0.5    0.    ]
# Tan: [0.00000000e+00 5.80000000e-01 1.00000000e+00 1.73000000e+00
#  1.63312394e+16]
