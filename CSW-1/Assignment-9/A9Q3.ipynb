# %%
import numpy as np

arr = np.array([1, 2, 4, 8, 16])

print("Natural log:", np.log(arr))
print("Log base 10:", np.log10(arr))
print("Log base 2:", np.log2(arr))
print("Exponential:", np.exp(arr))
# Out:
# Natural log: [0.         0.69314718 1.38629436 2.07944154 2.77258872]
# Log base 10: [0.         0.30103    0.60205999 0.90308999 1.20411998]
# Log base 2: [0. 1. 2. 3. 4.]
# Exponential: [2.71828183e+00 7.38905610e+00 5.45981500e+01 2.98095799e+03
#  8.88611052e+06]
