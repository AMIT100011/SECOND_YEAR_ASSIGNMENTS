# %%
import numpy as np
import  matplotlib.pyplot as plt
x = np.linspace(0,2*np.pi,50)
plt.plot(x,np.sin(x),label="sine",color='blue')
plt.plot(x,np.cos(x),label="cosine",color = 'green')
plt.plot(x,np.tan(x),label="tangent",color='red')
plt.legend()
plt.show()
